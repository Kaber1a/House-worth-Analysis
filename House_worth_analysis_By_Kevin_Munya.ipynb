# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaber1a/House-worth-Analysis/blob/main/House_worth_analysis_By_Kevin_Munya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TITILE: HOUSE WORTH ANALYSIS

# %% [markdown]
# PROBLEM-SOLVING
#
# The objective aimed to get from this data set is to identify how certain factors such as prescence of StoreArea etc affect the pricing of the house thus the overall net worth of the house. This enables us to determine which factors are key to consider or to avoid while purchasing a house to the constrain of our budget.

# %%
#Load the necessary libraries to read the data set
#Assign the file path of the data set a name that will be assist in manipulation of the data set
#Read the data set
#display the data set for further analysis
import pandas as pd
fp=pd.read_csv("/content/M3_House_Worth (1).csv")
fp
# Out:
#      HousePrice  StoreArea  BasementArea   LawnArea HouseNetWorth
# 0        138800       29.9            75  11.223911           Low
# 1        155000       44.0           504   9.689869        Medium
# 2        152000       46.2           493  10.192613        Medium
# 3        160000       46.2           510   6.817316        Medium
# 4        226000       48.7           445  10.916215        Medium
# ..          ...        ...           ...        ...           ...
# 311       99900       59.8             0   7.982364           Low
# 312      290000       84.4           740  10.029866          High
# 313       67000       34.6            41   9.529874           Low
# 314      260000       66.0          1300  10.388070          High
# 315       84500        8.1             0  11.454849           Low
#
# [316 rows x 5 columns]

# %% [markdown]
# I have the loaded the data set then read it using the pandas library. After reading the data, the data set is then displayed for further analysis

# %% [markdown]
# DATA UNDERSTANDING

# %%
fp.head()
# Out:
#    HousePrice  StoreArea  BasementArea   LawnArea HouseNetWorth
# 0      138800       29.9            75  11.223911           Low
# 1      155000       44.0           504   9.689869        Medium
# 2      152000       46.2           493  10.192613        Medium
# 3      160000       46.2           510   6.817316        Medium
# 4      226000       48.7           445  10.916215        Medium

# %% [markdown]
# These are the first few rows of the data set

# %%
fp.tail()
# Out:
#      HousePrice  StoreArea  BasementArea   LawnArea HouseNetWorth
# 311       99900       59.8             0   7.982364           Low
# 312      290000       84.4           740  10.029866          High
# 313       67000       34.6            41   9.529874           Low
# 314      260000       66.0          1300  10.388070          High
# 315       84500        8.1             0  11.454849           Low

# %% [markdown]
# These are the last few rows of the data set

# %%
fp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316 entries, 0 to 315
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HousePrice     316 non-null    int64
#  1   StoreArea      316 non-null    float64
#  2   BasementArea   316 non-null    int64
#  3   LawnArea       316 non-null    float64
#  4   HouseNetWorth  316 non-null    object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 12.5+ KB

# %% [markdown]
# I have displayed important information of  the data set which includes the size of the data set which is 12.5KB , the data types present in the data set which are float , object and interger.
#
# This information will assist us in understanding the dataset and identify which trajectory to take while analysing the data in indepth

# %%
numeric_coloumn= [
    'HousePrice',
    'StoreArea',
    'BasementArea',
    'LawnArea',

]
numeric_fp = fp[numeric_coloumn]
numeric_fp
# Out:
#      HousePrice  StoreArea  BasementArea   LawnArea
# 0        138800       29.9            75  11.223911
# 1        155000       44.0           504   9.689869
# 2        152000       46.2           493  10.192613
# 3        160000       46.2           510   6.817316
# 4        226000       48.7           445  10.916215
# ..          ...        ...           ...        ...
# 311       99900       59.8             0   7.982364
# 312      290000       84.4           740  10.029866
# 313       67000       34.6            41   9.529874
# 314      260000       66.0          1300  10.388070
# 315       84500        8.1             0  11.454849
#
# [316 rows x 4 columns]

# %% [markdown]
# Before this step, the data type present in the data set were both textual and non textual. However, prescence of textual data type limits the analysis process hence there is need to convert the textual data type to numeric in order to make analysis. Hence through this step, I have converted the datatypes in the data set to numeric enabling smooth analysis.

# %%
numeric_fp.dtypes
# Out:
# HousePrice         int64
# StoreArea        float64
# BasementArea       int64
# LawnArea         float64
# HouseNetWorth     object
# dtype: object

# %% [markdown]
# I have confirmed the data set has been converted to numeric thus I can proceed with my analysis

# %% [markdown]
# DATA CLEANING
#
# Before analysing the data, I need to confirm no errors exist in the data set. Errors sucha as duplicates and missing values may lead to inaccuracy in my analysis.

# %%
numeric_fp.isnull().sum()
# Out:
# HousePrice       0
# StoreArea        0
# BasementArea     0
# LawnArea         0
# HouseNetWorth    0
# dtype: int64

# %% [markdown]
# The data set has no missing values

# %%
numeric_fp.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The data set has no duplicates

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
numeric_fp.describe()
# Out:
#           HousePrice   StoreArea  BasementArea    LawnArea
# count     316.000000  316.000000    316.000000  316.000000
# mean   213355.272152   48.312658    573.015823    9.913504
# std    122491.768329   24.722463    564.160849    1.558365
# min     39300.000000    1.800000      0.000000    6.213974
# 25%    115000.000000   27.000000      0.000000    9.211559
# 50%    173950.000000   47.600000    402.500000    9.922729
# 75%    294057.750000   67.300000   1107.000000   10.488359
# max    755000.000000  122.000000   2188.000000   21.539383

# %% [markdown]
# This is the summary statistics of the cleaned data set. The count highlights the total number of recorded rows in each of the column.The mean represets the average of each column
# The std is the standard deviation which highlights how each of the varibale has deviated from the mean
# The min represents the minimum value of the each variable
# The 25% which is the lower quartlie highlights that 1/4 of the data set lies below that value. Same to 50% and 75%
# The max highlights the highest value of each variable.

# %%
correlation_matrix = numeric_fp.corr()
correlation_matrix
# Out:
#               HousePrice  StoreArea  BasementArea  LawnArea
# HousePrice      1.000000   0.820399      0.896728  0.509821
# StoreArea       0.820399   1.000000      0.838730  0.408186
# BasementArea    0.896728   0.838730      1.000000  0.461518
# LawnArea        0.509821   0.408186      0.461518  1.000000

# %% [markdown]
# This shows how different variables co-rrelate. For example Store area and house price co-orelate by 82%. From this, we can conclude that Store are and house price are linearly related. If the store area increases the house price increases and vice versa.
#
# The correlation matrix is vital as it helps in visualising a heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# This is a representation of the co-orelation matrix visually. Co-relation above 0.5 (50%) , highlights that the 2 variables strongly relate with each other and vice versa. It enables us to graphically interpret how different varibles correlate with each other and what serves as a crucial factor in decision making.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in numeric_fp:
 plt.figure(figsize=(10, 8))
 values = numeric_fp[col]
 plt.bar(numeric_fp[col],values, color='blue')
 plt.xlabel(col)
 plt.ylabel('Values')
 plt.title(f'Distribution of {col}')
 plt.show()

# %% [markdown]
# I have used a bargraph to visually represnt distribution of the house price to the other variables(factors). All factors under analysis are linearly related to the house.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for col in numeric_fp:
 plt.figure(figsize=(10, 8))
 plt.scatter(numeric_fp[col], numeric_fp['HousePrice'])
 plt.xlabel(col)
 plt.ylabel('HousePrice')
 plt.title(f'Scatter Plot of {col} vs HousePrice')
 plt.show()

# %% [markdown]
# Yes, we have indentified that there exists a linearly relationship but plotting the scatter plot of the data set enables us to identify the concentration of the data despite there being a upward sloping linear relationship

# %% [markdown]
# FINDINGS
#
# 1.Lawn Area, StoreArea and Basement Area relate linearly to the House price
#
# 2.Basement Area co-orelates the highest to the house price at 90% followed by store area at 82% then Lawn area at 51%.
#
# 3.Excluding the house price, the store area and the basement area co-orelates the highest at  84% while Basement Are and Lawn Area co-orelates the lowest at 46%

# %% [markdown]
# CONCLUSIONS
#
# 1.Prescence of Lawn Area, Store Area and Basement Area altogether or individually increase the price of a house.
#
# 2.At the point where Lawn Area, Basement Area and Store Area have the same utility to a consumer and a consumer is debating whether to pick either of the three, the consumer should opt to purchase a house with a Lawn Area.
#
# 3.Basement Area has the highest affinity to increase house price followed by Store Area then Lawn Area having the least affinity.
